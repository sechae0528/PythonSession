# %%
import math
import numpy as np

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM KOPO_CHANNEL_SEASONALITY_NEW WHERE SUBSTR(YEARWEEK,5,2) <= 52', engine)

# %%
# 컬럼명 대문자
customerData.columns = [x.upper() for x in customerData.columns]

# %%
customerData=customerData.sort_values(["REGIONID","PRODUCT","YEARWEEK"], ascending=[True,True,True])
customerData
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY
# 298         A00  PRODUCT34   201401    661.0
# 1757        A00  PRODUCT34   201402    679.0
# 3125        A00  PRODUCT34   201403    578.0
# 205         A00  PRODUCT34   201404    532.0
# 4369        A00  PRODUCT34   201405    516.0
# 4313        A00  PRODUCT34   201406    423.0
# 6288        A00  PRODUCT34   201407    407.0
# 6403        A00  PRODUCT34   201408    364.0
# 5158        A00  PRODUCT34   201409    470.0
# 7437        A00  PRODUCT34   201410    538.0
# 10123       A00  PRODUCT34   201411    369.0
# 8844        A00  PRODUCT34   201412    352.0
# 10813       A00  PRODUCT34   201413    354.0
# 11274       A00  PRODUCT34   201414    312.0
# 12128       A00  PRODUCT34   201415    295.0
# 13437       A00  PRODUCT34   201416    284.0
# 13639       A00  PRODUCT34   201417    237.0
# 14444       A00  PRODUCT34   201418    180.0
# 15828       A00  PRODUCT34   201419    161.0
# 15458       A00  PRODUCT34   201420    140.0
# 17079       A00  PRODUCT34   201421    116.0
# 16966       A00  PRODUCT34   201422     98.0
# 17838       A00  PRODUCT34   201423     83.0
# 19465       A00  PRODUCT34   201424     71.0
# 49427       A00  PRODUCT34   201425     65.0
# 22468       A00  PRODUCT34   201426     60.0
# 49145       A00  PRODUCT34   201427     82.0
# 26940       A00  PRODUCT34   201428    151.0
# 27839       A00  PRODUCT34   201429    274.0
# 47552       A00  PRODUCT34   201430    532.0
# ...         ...        ...      ...      ...
# 74124       A77  PRODUCT12   201623   5348.0
# 65210       A77  PRODUCT12   201624   3275.0
# 60503       A77  PRODUCT12   201625   4158.0
# 100785      A77  PRODUCT12   201626   4815.0
# 123676      A77  PRODUCT12   201627   3002.0
# 103114      A77  PRODUCT12   201628   3319.0
# 91337       A77  PRODUCT12   201629   4200.0
# 121326      A77  PRODUCT12   201630   7120.0
# 96085       A77  PRODUCT12   201631   6345.0
# 100979      A77  PRODUCT12   201632   5863.0
# 100781      A77  PRODUCT12   201633   4211.0
# 123672      A77  PRODUCT12   201634   4019.0
# 121906      A77  PRODUCT12   201635   3624.0
# 108161      A77  PRODUCT12   201636   3742.0
# 111041      A77  PRODUCT12   201637   3002.0
# 117703      A77  PRODUCT12   201638   5583.0
# 112874      A77  PRODUCT12   201639  14734.0
# 117840      A77  PRODUCT12   201640   3603.0
# 116890      A77  PRODUCT12   201641   4010.0
# 120622      A77  PRODUCT12   201642   4292.0
# 92102       A77  PRODUCT12   201643   5760.0
# 107905      A77  PRODUCT12   201644   4109.0
# 98784       A77  PRODUCT12   201645   4506.0
# 98897       A77  PRODUCT12   201646   4255.0
# 102494      A77  PRODUCT12   201647   3574.0
# 101633      A77  PRODUCT12   201648   4152.0
# 96866       A77  PRODUCT12   201649   5086.0
# 101670      A77  PRODUCT12   201650   5846.0
# 100552      A77  PRODUCT12   201651   4933.0
# 91666       A77  PRODUCT12   201652   7551.0
#
# [123864 rows x 4 columns]

# %% [markdown]
# ### 음수(반품)는 0으로 고정

# %%
customerData["QTY"] = np.\
where(customerData["QTY"] <= 0, 1, customerData["QTY"])
customerData.head()
# Out:
#      REGIONID    PRODUCT YEARWEEK    QTY
# 298       A00  PRODUCT34   201401  661.0
# 1757      A00  PRODUCT34   201402  679.0
# 3125      A00  PRODUCT34   201403  578.0
# 205       A00  PRODUCT34   201404  532.0
# 4369      A00  PRODUCT34   201405  516.0

# %%
# 인덱스 다시 설정
sortedData = customerData.reset_index(drop=True)
sortedData.head(5)
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY
# 0      A00  PRODUCT34   201401  661.0
# 1      A00  PRODUCT34   201402  679.0
# 2      A00  PRODUCT34   201403  578.0
# 3      A00  PRODUCT34   201404  532.0
# 4      A00  PRODUCT34   201405  516.0

# %% [markdown]
# ### 이동평균(판매추세량) 함수

# %%
def sub_function(data):
    data = data.reset_index(drop=True)
    data["TEST"]=data["QTY"].rolling(window=13,center=True).mean()
    
    suborder=math.floor(13/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['QTY'][0:i+suborder+1].mean())
        data.loc[i,"TEST"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['QTY'][-i-suborder-1:].mean())
        data['TEST'][maxLength-i]=list1[i]
        
    return data

# %% [markdown]
# ### 정제된 판매량의 이동평균 함수

# %%
def smoo_function(data):
    data = data.reset_index(drop=True)
    data["SMOOTH"]=data["REFINE_QTY"].rolling(window=5,center=True).mean()
    
    suborder=math.floor(5/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['REFINE_QTY'][0:i+suborder+1].mean())
        data.loc[i,"SMOOTH"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['REFINE_QTY'][-i-suborder-1:].mean())
        data['SMOOTH'][maxLength-i]=list1[i]
        
    return data

# %% [markdown]
# ### 변동률(판매추세량의 표준편차) 함수

# %%
def std_function(data):
    data = data.reset_index(drop=True)
    data["STDEV"]=data["TEST"].rolling(window=5,center=True).std()
    
    suborder=math.floor(5/2)
   
    list=[]
    maxLength=len(data)-1
    for i in range(0,suborder):
        list.append(data['TEST'][0:i+suborder+1].std())
        data.loc[i,"STDEV"]=list[i]
    
    list1=[]
    for i in range(0,suborder):
        list1.append(data['TEST'][-i-suborder-1:].std())
        data['STDEV'][maxLength-i]=list1[i]
        
    return data

# %% [markdown]
# #### 이동평균(판매추세량) 구하기

# %%
groupResult = sortedData.groupby(['REGIONID','PRODUCT']).apply(sub_function)
aa=groupResult.reset_index(drop=True)

# %%
aa.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY        TEST
# 0      A00  PRODUCT34   201401  661.0  542.285714
# 1      A00  PRODUCT34   201402  679.0  520.000000
# 2      A00  PRODUCT34   201403  578.0  514.444444
# 3      A00  PRODUCT34   201404  532.0  516.800000
# 4      A00  PRODUCT34   201405  516.0  503.363636

# %% [markdown]
# #### 변동률 구하기

# %%
bb = aa.groupby(['REGIONID','PRODUCT']).apply(std_function)

# %% [markdown]
# #### 상한/하한구하기

# %%
bb["HIGH"]=bb["TEST"]+bb["STDEV"]
bb["LOW"]=bb["TEST"]-bb["STDEV"]

# %% [markdown]
# #### 정제된 판매량 구하기

# %%
bb['REFINE_QTY']=np.where(bb['QTY']>bb['HIGH'],bb['TEST'],\
        np.where(bb['QTY']<bb['LOW'],bb['TEST'],bb['QTY']))

# %% [markdown]
# #### 스무딩처리 구하기

# %%
cc = bb.groupby(['REGIONID','PRODUCT']).apply(smoo_function)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'REGIONID' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'PRODUCT' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
dd=cc.reset_index(drop=True)
dd.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY        TEST      STDEV        HIGH  \
# 0      A00  PRODUCT34   201401  661.0  542.285714  14.734617  557.020331
# 1      A00  PRODUCT34   201402  679.0  520.000000  12.806131  532.806131
# 2      A00  PRODUCT34   201403  578.0  514.444444  14.253036  528.697481
# 3      A00  PRODUCT34   201404  532.0  516.800000  12.002994  528.802994
# 4      A00  PRODUCT34   201405  516.0  503.363636  15.591135  518.954771
#
#           LOW  REFINE_QTY      SMOOTH
# 0  527.551098  542.285714  525.576720
# 1  507.193869  520.000000  523.382540
# 2  500.191408  514.444444  521.906032
# 3  504.797006  516.800000  511.598889
# 4  487.772501  516.000000  503.645043

# %% [markdown]
# ### 계절성지수산출(안정된 시장/ 불안정 시장)
# #### 안정된 시장 = 실제판매량/스무딩처리   || 불안정 시장 = 정제된 판매량/스무딩처리

# %%
dd["STABLE"] = np.where(dd['SMOOTH']==0,dd['QTY'],dd["QTY"]/dd["SMOOTH"])
dd["UNSTABLE"] = np.where(dd['SMOOTH']==0,dd['REFINE_QTY'],dd["REFINE_QTY"]/dd["SMOOTH"])
dd
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY         TEST       STDEV  \
# 0           A00  PRODUCT34   201401    661.0   542.285714   14.734617
# 1           A00  PRODUCT34   201402    679.0   520.000000   12.806131
# 2           A00  PRODUCT34   201403    578.0   514.444444   14.253036
# 3           A00  PRODUCT34   201404    532.0   516.800000   12.002994
# 4           A00  PRODUCT34   201405    516.0   503.363636   15.591135
# 5           A00  PRODUCT34   201406    423.0   490.750000   24.122226
# 6           A00  PRODUCT34   201407    407.0   480.230769   31.835969
# 7           A00  PRODUCT34   201408    364.0   453.384615   37.577643
# 8           A00  PRODUCT34   201409    470.0   423.846154   40.469705
# 9           A00  PRODUCT34   201410    538.0   401.230769   39.050923
# 10          A00  PRODUCT34   201411    369.0   378.538462   36.567721
# 11          A00  PRODUCT34   201412    352.0   352.692308   35.529528
# 12          A00  PRODUCT34   201413    354.0   332.538462   33.564060
# 13          A00  PRODUCT34   201414    312.0   312.000000   34.314875
# 14          A00  PRODUCT34   201415    295.0   292.923077   40.540410
# 15          A00  PRODUCT34   201416    284.0   264.307692   43.641337
# 16          A00  PRODUCT34   201417    237.0   229.307692   43.686328
# 17          A00  PRODUCT34   201418    180.0   206.384615   39.767170
# 18          A00  PRODUCT34   201419    161.0   184.307692   34.077505
# 123852  5039.016380  4929.291312  4984.153846  5034.092308  0.796569  0.990080
# 123853  5172.674250  4876.864212  5024.769231  5100.476923  0.841490  0.985157
# 123854  5289.273978  4967.033714  5128.153846  5156.184615  1.117105  0.994564
# 123855  5587.923899  5105.922254  5346.923077  5108.230769  0.804388  1.046727
# 123856  5566.511210  5027.334944  5296.923077  5071.176923  0.888551  1.044516
# 123857  5019.516241  4469.252989  4744.384615  5028.527972  0.846172  0.943494
# 123858  5049.684284  4629.315716  4839.500000  4954.583357  0.721352  0.976772
# 123859  5002.336902  4827.481280  4914.909091  4873.243186  0.851999  1.008550
# 123860  5038.951309  4915.448691  4977.200000  4910.966263  1.035641  1.013487
# 123861  4955.765516  4824.678929  4890.222222  4954.409120  1.179959  0.987044
# 123862  5056.185645  4919.564355  4933.000000  4964.284127  0.993698  0.993698
# 123863  5140.374829  4973.053742  5056.714286  4959.978836  1.522386  1.019503
#
# [123864 rows x 12 columns]

# %%
#dd.to_csv('d:/middleTest_03.csv')
dd.head()
len(dd)
# Out:
# 123864

# %%
import pymysql

# %%
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 
engine11 = create_engine('postgresql://kopo:kopo@192.168.110.111:5432/kopo') 
engine12 = create_engine('mysql+pymysql://root:P@ssw0rd@192.168.110.112:3306/kopo')

# %%
for i in dd:
    dd.to_sql()

resultname='result_py11'
dd.to_sql(resultname, engine, if_exists='replace', index=False)

# %%
dd.head(2)
# Out:
#   REGIONID    PRODUCT YEARWEEK    QTY        TEST      STDEV        HIGH  \
# 0      A00  PRODUCT34   201401  661.0  542.285714  14.734617  557.020331
# 1      A00  PRODUCT34   201402  679.0  520.000000  12.806131  532.806131
#
#           LOW  REFINE_QTY      SMOOTH    STABLE  UNSTABLE
# 0  527.551098  557.020331  539.507981  1.225190  1.032460
# 1  507.193869  532.806131  536.831734  1.264828  0.992501

# %%
dd.dtypes
# Out:
# REGIONID       object
# PRODUCT        object
# YEARWEEK       object
# QTY           float64
# TEST          float64
# STDEV         float64
# HIGH          float64
# LOW           float64
# REFINE_QTY    float64
# SMOOTH        float64
# STABLE        float64
# UNSTABLE      float64
# dtype: object

# %%
import seaborn as sns
# %matplotlib inline
tc = dd.corr()
sns.heatmap(tc, annot = True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(x='YEARWEEK', y = 'STABLE', data = dd, fit_reg=False)

# %%
fig = plt.figure()

x = fig.add_axes(dd['STABLE'])
y = fig.add_axes(dd['YEARWEEK'])

ax1 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

ax1.plot(x , y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-cc647b4f172b> in <module>()
#       1 fig = plt.figure()
#       2
# ----> 3 x = fig.add_axes(dd['STABLE'])
#       4 y = fig.add_axes(dd['YEARWEEK'])
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_axes(self, *args, **kwargs)
#     968
#     969             # create the new axes using the axes class given
# --> 970             a = projection_class(self, rect, **kwargs)
#     971
#     972         self._axstack.add(key, a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     484             self._position = rect
#     485         else:
# --> 486             self._position = mtransforms.Bbox.from_bounds(*rect)
#     487         if self._position.width < 0 or self._position.height < 0:
#     488             raise ValueError('Width and height specified must be non-negative')
#
# TypeError: from_bounds() takes 4 positional arguments but 124658 were given
